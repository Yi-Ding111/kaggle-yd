# %% [markdown]
# This notebook is to have a look at the train metadata info

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',None)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../../data/train_metadata.csv',header=0)

# %%
display(df)
# Out:
#       primary_label secondary_labels      type  latitude  longitude  \
# 0            asbfly               []  ['call']   39.2297   118.1987
# 1            asbfly               []  ['song']   51.4030   104.6401
# 2            asbfly               []  ['song']   36.3319   127.3555
# 3            asbfly               []  ['call']   21.1697    70.6005
# 4            asbfly               []  ['call']   15.5442    73.7733
# ...             ...              ...       ...       ...        ...
# 24454       zitcis1               []      ['']   43.5925     4.5434
# 24455       zitcis1               []      ['']   43.5925     4.5434
# 24456       zitcis1               []      ['']   51.1207     4.5607
# 24457       zitcis1               []      ['']   41.5607    -8.4236
# 24458       zitcis1               []      ['']   13.7747   100.8919
#
#           scientific_name             common_name  \
# 0      Muscicapa dauurica  Asian Brown Flycatcher
# ...

# %%
df.loc[0,'filename']
# Out:
# 'asbfly/XC134896.ogg'

# %% [markdown]
# ### Actually The info in this df, the only thing I really care about is primary label and filename

# %%
# check the count of the promary labels

label_num=df.primary_label.nunique()
print('total label numbers:',label_num)

label_list=df.primary_label.unique()

print('total unqiue labels:', label_list)
# Out:
# total label numbers: 182
# total unqiue labels: ['asbfly' 'ashdro1' 'ashpri1' 'ashwoo2' 'asikoe2' 'asiope1' 'aspfly1'
#  'aspswi1' 'barfly1' 'barswa' 'bcnher' 'bkcbul1' 'bkrfla1' 'bkskit1'
#  'bkwsti' 'bladro1' 'blaeag1' 'blakit1' 'blhori1' 'blnmon1' 'blrwar1'
#  'bncwoo3' 'brakit1' 'brasta1' 'brcful1' 'brfowl1' 'brnhao1' 'brnshr'
#  'brodro1' 'brwjac1' 'brwowl1' 'btbeat1' 'bwfshr1' 'categr' 'chbeat1'
#  'cohcuc1' 'comfla1' 'comgre' 'comior1' 'comkin1' 'commoo3' 'commyn'
#  'compea' 'comros' 'comsan' 'comtai1' 'copbar1' 'crbsun2' 'cregos1'
#  'crfbar1' 'crseag1' 'dafbab1' 'darter2' 'eaywag1' 'emedov2' 'eucdov'
#  'eurbla2' 'eurcoo' 'forwag1' 'gargan' 'gloibi' 'goflea1' 'graher1'
#  'grbeat1' 'grecou1' 'greegr' 'grefla1' 'grehor1' 'grejun2' 'grenig1'
#  'grewar3' 'grnsan' 'grnwar1' 'grtdro1' 'gryfra' 'grynig2' 'grywag'
#  'gybpri1' 'gyhcaf1' 'heswoo1' 'hoopoe' 'houcro1' 'houspa' 'inbrob1'
#  'indpit1' 'indrob1' 'indrol2' 'indtit1' 'ingori1' 'inpher1' 'insbab1'
# ...

# %%
label_counts = df['primary_label'].value_counts()

print(label_counts)
# Out:
# primary_label
# zitcis1    500
# lirplo     500
# litgre1    500
# comgre     500
# comkin1    500
#           ...
# blaeag1      6
# wynlau1      6
# niwpig1      5
# asiope1      5
# integr       5
# Name: count, Length: 182, dtype: int64

# %%
# visualize the distribution of each category

plt.figure(figsize=(45, 10))
ax = sns.barplot(x=label_counts.index, y=label_counts.values, palette="hls")


plt.title("Bird Species", fontsize=16)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=13)
plt.ylabel("Frequency", fontsize=20)
plt.xlabel("Bird Species", fontsize=20)
plt.gcf().set_facecolor('#33FFE3')  # Set background color of the entire figure

plt.show()
# Out:
# /var/folders/5b/b2jjkdb55_g_qzx3lsl5k59m0000gn/T/ipykernel_25711/1921819714.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=label_counts.index, y=label_counts.values, palette="hls")

# %% [markdown]
# **Next I want to check if the primary_label 100 percent fit with the suffix of file name**

# %%
df['file_name_suffix']=df['filename'].str.split('/').str[0]

display(df)
# Out:
#       primary_label secondary_labels      type  latitude  longitude  \
# 0            asbfly               []  ['call']   39.2297   118.1987
# 1            asbfly               []  ['song']   51.4030   104.6401
# 2            asbfly               []  ['song']   36.3319   127.3555
# 3            asbfly               []  ['call']   21.1697    70.6005
# 4            asbfly               []  ['call']   15.5442    73.7733
# ...             ...              ...       ...       ...        ...
# 24454       zitcis1               []      ['']   43.5925     4.5434
# 24455       zitcis1               []      ['']   43.5925     4.5434
# 24456       zitcis1               []      ['']   51.1207     4.5607
# 24457       zitcis1               []      ['']   41.5607    -8.4236
# 24458       zitcis1               []      ['']   13.7747   100.8919
#
#           scientific_name             common_name  \
# 0      Muscicapa dauurica  Asian Brown Flycatcher
# ...

# %%
df['ifmatch']= (df['primary_label']==df['file_name_suffix']).astype(int)

# %%
df.ifmatch.nunique()
# Out:
# 1

# %% [markdown]
# This represents all suffix are correct, we could use the folder name to re construct the df we need for the model

# %% [markdown]
# ### look at the rating range and value. The rating represents the quality of the audio data.

# %%
df['rating'].nunique()
# Out:
# 11

# %%
df['rating'].unique()
# Out:
# array([5. , 2.5, 4. , 3. , 3.5, 4.5, 0.5, 0. , 1.5, 2. , 1. ])

# %%
np.clip(df["rating"] / df["rating"].max(), 0.1, 1.0)
# Out:
# 0        1.0
# 1        0.5
# 2        0.5
# 3        0.8
# 4        0.8
#         ...
# 24454    1.0
# 24455    0.8
# 24456    0.8
# 24457    0.9
# 24458    1.0
# Name: rating, Length: 24459, dtype: float64

# %% [markdown]
# This means that the higher the rating, the better the quality, and 0 means that the corresponding audio is not rated.

# %%
# check if the rating has NAN values

missing_count = df['rating'].isna().sum()

missing_count
# Out:
# 0

# %%
# check how many values equal to 0

len(df[df['rating']==0])

# This number is small, so we can randomly interpolate and give the target audio a random level division.
# Out:
# 603
